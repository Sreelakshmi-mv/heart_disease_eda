# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    "age": [63, 37, 41, 56, 57, 57, 56, 44],
    "sex": [1, 1, 0, 1, 0, 1, 0, 1],
    "cp": [3, 2, 1, 1, 0, 0, 1, 2],
    "trestbps": [145, 130, 130, 120, 120, 140, 140, 120],
    "chol": [233, 250, 204, 236, 354, 192, 294, 263],
    "fbs": [1, 0, 0, 0, 0, 0, 0, 0],
    "thalach": [150, 187, 172, 178, 163, 148, 153, 173],
    "target": [1, 1, 1, 1, 0, 1, 0, 0]
}

df = pd.DataFrame(data)
df
# Out:
#    age  sex  cp  trestbps  chol  fbs  thalach  target
# 0   63    1   3       145   233    1      150       1
# 1   37    1   2       130   250    0      187       1
# 2   41    0   1       130   204    0      172       1
# 3   56    1   1       120   236    0      178       1
# 4   57    0   0       120   354    0      163       0
# 5   57    1   0       140   192    0      148       1
# 6   56    0   1       140   294    0      153       0
# 7   44    1   2       120   263    0      173       0

# %%
df.shape
# Out:
# (8, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       8 non-null      int64
#  1   sex       8 non-null      int64
#  2   cp        8 non-null      int64
#  3   trestbps  8 non-null      int64
#  4   chol      8 non-null      int64
#  5   fbs       8 non-null      int64
#  6   thalach   8 non-null      int64
#  7   target    8 non-null      int64
# dtypes: int64(8)
# memory usage: 644.0 bytes

# %%
df.describe()
# Out:
#              age       sex        cp    trestbps        chol       fbs  \
# count   8.000000  8.000000  8.000000    8.000000    8.000000  8.000000
# mean   51.375000  0.625000  1.250000  130.625000  253.250000  0.125000
# std     9.334077  0.517549  1.035098   10.155048   51.825945  0.353553
# min    37.000000  0.000000  0.000000  120.000000  192.000000  0.000000
# 25%    43.250000  0.000000  0.750000  120.000000  225.750000  0.000000
# 50%    56.000000  1.000000  1.000000  130.000000  243.000000  0.000000
# 75%    57.000000  1.000000  2.000000  140.000000  270.750000  0.000000
# max    63.000000  1.000000  3.000000  145.000000  354.000000  1.000000
#
#           thalach    target
# count    8.000000  8.000000
# mean   165.500000  0.625000
# std     14.272851  0.517549
# min    148.000000  0.000000
# 25%    152.250000  0.000000
# 50%    167.500000  1.000000
# 75%    174.250000  1.000000
# max    187.000000  1.000000

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# thalach     0
# target      0
# dtype: int64

# %%
sns.countplot(x="target", data=df)
plt.title("Heart Disease Target Distribution (Dummy Data)")
plt.show()

# %%
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
import matplotlib.pyplot as plt

# Example plot
plt.plot([1, 2, 3], [4, 5, 6])
plt.title("Sample Plot")

# Save as image in the repo folder
plt.savefig("plot.png")  # This will save in the current working directory
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram
sns.histplot(df['age'], bins=20)
plt.show()

# Correlation heatmap
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

# Save the heatmap figure
plt.savefig("correlation_heatmap.png")
